# %%
from __future__ import print_function
print("Hello World!")
# Out:
# Hello World!

# %%
a,b,c=3,4.5,'hey buy'
print(a)
print(b)
print(c)
# Out:
# 3
# 4.5
# hey buy

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("chicago-employees.csv")

# %%
df1=df.copy()

# %%
df1.iloc[:11,3]=np.nan

# %%
df1
# Out:
#                         Name                              Job Titles  \
# 0          AARON,  JEFFERY M                                SERGEANT
# 1            AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2        AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER
# 3        ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 4         ABARCA,  EMMANUEL                         CONCRETE LABORER
# ...                      ...                                     ...
# 32807  ZYLINSKA,  KATARZYNA                           POLICE OFFICER
# 32808     ZYMANTAS,  LAURA C                          POLICE OFFICER
# 32809      ZYMANTAS,  MARK E                          POLICE OFFICER
# 32810    ZYRKOWSKI,  CARLO E                          POLICE OFFICER
# 32811   ZYSKOWSKI,  DARIUSZ                  CHIEF DATA BASE ANALYST
#
#              Department Full or Part-Time Salary or Hourly  Typical Hours  \
# ...

# %%
a=np.array([1,3,5,2,5,8,2,7,9])
b=np.array([4,3,7,1,8,3,7,2,3])
np.intersect1d(a,b)
# Out:
# array([1, 2, 3, 7, 8])

# %%
ser=pd.Series(['mary','had','a','little','lamp'])

# %%
ser.map(lambda x: x.title())
# Out:
# 0      Mary
# 1       Had
# 2         A
# 3    Little
# 4      Lamp
# dtype: object

# %%
ser.map(lambda x: len(x))
# Out:
# 0    4
# 1    3
# 2    1
# 3    6
# 4    4
# dtype: int64

# %%
df1.rename(columns={ 'Job Titles': 'Job_Titles'},)
# Out:
#                         Name                              Job_Titles  \
# 0          AARON,  JEFFERY M                                SERGEANT
# 1            AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2        AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER
# 3        ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 4         ABARCA,  EMMANUEL                         CONCRETE LABORER
# ...                      ...                                     ...
# 32807  ZYLINSKA,  KATARZYNA                           POLICE OFFICER
# 32808     ZYMANTAS,  LAURA C                          POLICE OFFICER
# 32809      ZYMANTAS,  MARK E                          POLICE OFFICER
# 32810    ZYRKOWSKI,  CARLO E                          POLICE OFFICER
# 32811   ZYSKOWSKI,  DARIUSZ                  CHIEF DATA BASE ANALYST
#
#              Department Full or Part-Time Salary or Hourly  Typical Hours  \
# ...
