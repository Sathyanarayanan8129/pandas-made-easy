# %%
import psycopg2

# %%
conn=psycopg2.connect(database="Course_data",
                      user="postgres",
                      password="rohini28")

# %%
crsr=conn.cursor()

# %%
crsr.execute("select * from employees where department ='Sports'")

# %%
crsr.fetchall()
# Out:
# [(1,
#   'Berrie',
#   'Manueau',
#   'bmanueau0@dion.ne.jp',
#   datetime.date(2006, 4, 20),
#   'Sports',
#   'F',
#   154864,
#   4),
#  (6,
#   'Bethena',
#   'Trow',
#   'btrow5@technorati.com',
#   datetime.date(2003, 6, 8),
#   'Sports',
#   'F',
#   134501,
#   3),
#  (34,
#   'Lucy',
#   'Olifaunt',
#   'lolifauntx@dailymotion.com',
#   datetime.date(2005, 2, 7),
#   'Sports',
#   'F',
#   165660,
#   7),
#  (51,
#   'Norine',
#   'Steinham',
#   None,
#   datetime.date(2008, 8, 22),
#   'Sports',
#   'F',
#   66488,
#   2),
#  (77,
#   'Maurice',
#   'Philbrick',
#   None,
#   datetime.date(2006, 1, 8),
#   'Sports',
#   'M',
#   67615,
#   1),
#  (89,
#   'Claudetta',
#   'Sappson',
#   'csappson2g@aboutads.info',
#   datetime.date(2011, 8, 24),
#   'Sports',
#   'F',
#   157802,
#   5),
#  (156,
#   'Joleen',
#   'Rothwell',
#   'jrothwell4b@fastcompany.com',
#   datetime.date(2004, 10, 24),
#   'Sports',
#   'F',
#   29838,
#   2),
#  (164,
#   'Benjamin',
#   'Younie',
# ...

# %%
crsr.close()

# %%
conn.close()

# %%
conn=psycopg2.connect(database="Course_data",
                      user="postgres",
                      password="rohini28")

# %%
cur=conn.cursor()

# %%
cur.execute("select * from departments")

# %%
cur.fetchall()
# Out:
# [('Clothing', 'Home'),
#  ('Grocery', 'Home'),
#  ('Decor', 'Home'),
#  ('Furniture', 'Home'),
#  ('Computers', 'Electronics'),
#  ('Device Repair', 'Electronics'),
#  ('Phones & Tablets', 'Electronics'),
#  ('Garden', 'Outdoors'),
#  ('Camping & Fishing', 'Outdoors'),
#  ('Sports', 'Outdoors'),
#  ('Children Clothing', 'Kids'),
#  ('Toys', 'Kids'),
#  ('Vitamins', 'Health'),
#  ('Pharmacy', 'Health'),
#  ('First Aid', 'Health'),
#  ('Automotive', 'Hardware'),
#  ('Tools', 'Hardware'),
#  ('Jewelry', 'Fashion'),
#  ('Beauty', 'Fashion'),
#  ('Cosmetics', 'Fashion'),
#  ('Books', 'Entertainment'),
#  ('Games', 'Entertainment'),
#  ('Music', 'Entertainment'),
#  ('Movies', 'Entertainment')]
